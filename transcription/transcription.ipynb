# %% [markdown]
# ## Project Setup
#
# I have already installed the Google Cloud SDK for Python and then added:
#
# ```pip install --upgrade google-cloud-speech```
#
# I have already enabled the [Google Cloud Speech-to-Text API](https://cloud.google.com/speech-to-text/docs/libraries) in my Google Cloud project. I've also set the required environment variable for my Google Cloud credentials.
#
# ```export GOOGLE_APPLICATION_CREDENTIALS="/PATH/TO/CREDENTIALS"```
#
# And—maybe more importantly—I've already recorded a couple of sample audio clips. The API is quite particular as to how it wants these clips formatted. [The documentation](https://cloud.google.com/speech-to-text/docs/encoding) is well written, but you have to remember it's an issue first.
#
# You could do this in Python itself, but honestly, it's a lot easier to use `ffmpeg` to do it for you. The command you're looking for (which also handles video files) is:
#
# ```ffmpeg -y -i INPUT_FILE -vn -ar 44100 -ac 1 -ab 192k -f wav -loglevel panic OUTPUT_FILE```
#
# Don't worry if you forget, the numerous and constant onslaught of error messages will remind you. 🤣😔
#
# My samples are currently formatted as 44100 KHz, single channel (mono), .wav files.

# %% [markdown]
# ## Code Init

# %%
# From the Google Cloud SDK
from google.cloud import speech
from google.cloud import speech_v1p1beta1 as speech
from google.cloud import storage # required for longer files

# %%
# Sample file paths
fp_samples = [
    'samples/audio-sample-01.m4a', # 10 second sample, incorrectly formatted
    'samples/audio-sample-01.wav', # 10 second sample, correctly formatted
    'samples/audio-sample-02.wav', # 3+ minute sample, correctly formatted
]

# %%
# Handy function to upload a file to Google Cloud Storage and return the GS URI
import os
def upload_file(fp, bucket_name):
    """
    Upload the specified file to the specified Google Cloud Storage bucket
    """
    result = None

    if not os.path.exists(fp): return result
    
    storage_client = storage.Client()
    bucket = storage_client.get_bucket(bucket_name)

    blob_fn = os.path.basename(fp)
    blob = bucket.blob(blob_fn)    

    try:
        blob.upload_from_filename(fp)
        print("Uploaded [{}] to Google Cloud Storage bucket [{}]".format(blob_fn, bucket_name))
        result = "gs://{}/{}".format(bucket_name, blob_fn)
    except Exception as err:
        print("Could not upload [{}] to Google Cloud Storage bucket [{}]. Threw exception:\n{}\n".format(fp, bucket_name, err))

    return result

# %%
# Upload the samples to the Google Cloud Storage bucket and save the GCS paths
gcs_samples = []
for fp in fp_samples:
    gcs_uri = upload_file(fp, 'tcp-data')
    if gcs_uri:
        gcs_samples.append(gcs_uri)
    
print("\n".join(gcs_samples))
# Out:
# Uploaded [audio-sample-01.m4a] to Google Cloud Storage bucket [tcp-data]
# Uploaded [audio-sample-01.wav] to Google Cloud Storage bucket [tcp-data]
# Uploaded [audio-sample-02.wav] to Google Cloud Storage bucket [tcp-data]
# gs://tcp-data/audio-sample-01.m4a
# gs://tcp-data/audio-sample-01.wav
# gs://tcp-data/audio-sample-02.wav

# %%
client = speech.SpeechClient()
audio = speech.types.RecognitionAudio(uri=gcs_samples[-1])
config = speech.types.RecognitionConfig(
    sample_rate_hertz=44100,
    language_code='en-US',
    enable_word_time_offsets=True,
    enable_automatic_punctuation=True,
    enable_speaker_diarization=True,
    diarization_speaker_count=2)
    
results = None
try:
    operation = client.long_running_recognize(config=config, audio=audio)
    print('Waiting for transcription operation to complete...')
    response = operation.result(timeout=3000)
    results = response.results
except Exception as err:
    print("Could not transcribe audio file. Threw exception:\n{}\n".format(err))

if results:
    print(results)
# Out:
# Waiting for transcription operation to complete...
# [alternatives {
#   transcript: "This is from an article called updates on the twitch security. Incident posted to the twitch blog on October 6th, 2021 update regarding stream keys out of an abundance of caution. We have reset all stream key so you can get your new stream key here. Then it listen to around, depending on which broadcast offer you use. You may need to manually update yourself, or with this new key to start your next stream. Twitch Studio streamlabs Xbox PlayStation, and twitch mobile app users. Do not need to take any action for your new key to work OBS users who connected their Twitter account. Should also not need to take any action lbs users that if not connected their Twitter account. OBS will need to manually copy their string key for their twitch dashboard and paste it into OBS, for all others. Please refer to specific, set up instructions for the software virtuous, and there\'s an update late on the night of October 6th 2021 at 10:30 p.m. Pacific time. We\'ve learned that some data was exposed to the internet due to an error in at which server configuration change. That was subsequently accessed by them."
#   confidence: 0.9625437
#   words {
#     start_time {
#       seconds: 1
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 100000000
#     }
#     word: "This"
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 200000000
#     }
#     word: "is"
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 400000000
#     }
#     word: "from"
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 500000000
#     }
#     word: "an"
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 900000000
#     }
#     word: "article"
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 3
#       nanos: 100000000
#     }
#     word: "called"
#   }
#   words {
#     start_time {
#       seconds: 3
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 3
#       nanos: 700000000
#     }
#     word: "updates"
#   }
#   words {
#     start_time {
#       seconds: 3
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 3
#       nanos: 700000000
#     }
#     word: "on"
#   }
#   words {
#     start_time {
#       seconds: 3
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 3
#       nanos: 900000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 3
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 4
#       nanos: 100000000
#     }
#     word: "twitch"
#   }
#   words {
#     start_time {
#       seconds: 4
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 4
#       nanos: 600000000
#     }
#     word: "security."
#   }
#   words {
#     start_time {
#       seconds: 4
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 5
#     }
#     word: "Incident"
#   }
#   words {
#     start_time {
#       seconds: 5
#     }
#     end_time {
#       seconds: 5
#       nanos: 500000000
#     }
#     word: "posted"
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 600000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 700000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 900000000
#     }
#     word: "twitch"
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 6
#       nanos: 300000000
#     }
#     word: "blog"
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 6
#       nanos: 400000000
#     }
#     word: "on"
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 6
#       nanos: 800000000
#     }
#     word: "October"
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     word: "6th,"
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 100000000
#     }
#     word: "2021"
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 9
#       nanos: 400000000
#     }
#     word: "update"
#   }
#   words {
#     start_time {
#       seconds: 9
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 9
#       nanos: 700000000
#     }
#     word: "regarding"
#   }
#   words {
#     start_time {
#       seconds: 9
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 10
#       nanos: 300000000
#     }
#     word: "stream"
#   }
#   words {
#     start_time {
#       seconds: 10
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 10
#       nanos: 700000000
#     }
#     word: "keys"
#   }
#   words {
#     start_time {
#       seconds: 10
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 11
#     }
#     word: "out"
#   }
#   words {
#     start_time {
#       seconds: 11
#     }
#     end_time {
#       seconds: 11
#       nanos: 200000000
#     }
#     word: "of"
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     word: "an"
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 500000000
#     }
#     word: "abundance"
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 900000000
#     }
#     word: "of"
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 12
#       nanos: 100000000
#     }
#     word: "caution."
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 12
#       nanos: 600000000
#     }
#     word: "We"
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 12
#       nanos: 800000000
#     }
#     word: "have"
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 500000000
#     }
#     word: "reset"
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 800000000
#     }
#     word: "all"
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 14
#       nanos: 200000000
#     }
#     word: "stream"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 14
#       nanos: 400000000
#     }
#     word: "key"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 14
#       nanos: 700000000
#     }
#     word: "so"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 14
#       nanos: 800000000
#     }
#     word: "you"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 14
#       nanos: 800000000
#     }
#     word: "can"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 15
#     }
#     word: "get"
#   }
#   words {
#     start_time {
#       seconds: 15
#     }
#     end_time {
#       seconds: 15
#       nanos: 100000000
#     }
#     word: "your"
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 15
#       nanos: 300000000
#     }
#     word: "new"
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 15
#       nanos: 600000000
#     }
#     word: "stream"
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 15
#       nanos: 800000000
#     }
#     word: "key"
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 200000000
#     }
#     word: "here."
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 500000000
#     }
#     word: "Then"
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 600000000
#     }
#     word: "it"
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 900000000
#     }
#     word: "listen"
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 900000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 17
#       nanos: 200000000
#     }
#     word: "around,"
#   }
#   words {
#     start_time {
#       seconds: 17
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 17
#       nanos: 900000000
#     }
#     word: "depending"
#   }
#   words {
#     start_time {
#       seconds: 17
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 100000000
#     }
#     word: "on"
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 200000000
#     }
#     word: "which"
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 300000000
#     }
#     word: "broadcast"
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 900000000
#     }
#     word: "offer"
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 200000000
#     }
#     word: "you"
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 500000000
#     }
#     word: "use."
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 700000000
#     }
#     word: "You"
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 800000000
#     }
#     word: "may"
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 20
#     }
#     word: "need"
#   }
#   words {
#     start_time {
#       seconds: 20
#     }
#     end_time {
#       seconds: 20
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 20
#     }
#     end_time {
#       seconds: 20
#       nanos: 400000000
#     }
#     word: "manually"
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 500000000
#     }
#     word: "update"
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 900000000
#     }
#     word: "yourself,"
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 300000000
#     }
#     word: "or"
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 500000000
#     }
#     word: "with"
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 600000000
#     }
#     word: "this"
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 800000000
#     }
#     word: "new"
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 22
#     }
#     word: "key"
#   }
#   words {
#     start_time {
#       seconds: 22
#     }
#     end_time {
#       seconds: 22
#       nanos: 100000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 400000000
#     }
#     word: "start"
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 500000000
#     }
#     word: "your"
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 800000000
#     }
#     word: "next"
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 23
#     }
#     word: "stream."
#   }
#   words {
#     start_time {
#       seconds: 23
#     }
#     end_time {
#       seconds: 23
#       nanos: 900000000
#     }
#     word: "Twitch"
#   }
#   words {
#     start_time {
#       seconds: 23
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 24
#       nanos: 100000000
#     }
#     word: "Studio"
#   }
#   words {
#     start_time {
#       seconds: 24
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 25
#       nanos: 100000000
#     }
#     word: "streamlabs"
#   }
#   words {
#     start_time {
#       seconds: 25
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 25
#       nanos: 600000000
#     }
#     word: "Xbox"
#   }
#   words {
#     start_time {
#       seconds: 25
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 26
#     }
#     word: "PlayStation,"
#   }
#   words {
#     start_time {
#       seconds: 26
#     }
#     end_time {
#       seconds: 26
#       nanos: 300000000
#     }
#     word: "and"
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 500000000
#     }
#     word: "twitch"
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 700000000
#     }
#     word: "mobile"
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 27
#     }
#     word: "app"
#   }
#   words {
#     start_time {
#       seconds: 27
#     }
#     end_time {
#       seconds: 27
#       nanos: 300000000
#     }
#     word: "users."
#   }
#   words {
#     start_time {
#       seconds: 27
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 27
#       nanos: 500000000
#     }
#     word: "Do"
#   }
#   words {
#     start_time {
#       seconds: 27
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 27
#       nanos: 600000000
#     }
#     word: "not"
#   }
#   words {
#     start_time {
#       seconds: 27
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 27
#       nanos: 900000000
#     }
#     word: "need"
#   }
#   words {
#     start_time {
#       seconds: 27
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 28
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 28
#     }
#     end_time {
#       seconds: 28
#       nanos: 200000000
#     }
#     word: "take"
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 28
#       nanos: 500000000
#     }
#     word: "any"
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 28
#       nanos: 600000000
#     }
#     word: "action"
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 100000000
#     }
#     word: "for"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 200000000
#     }
#     word: "your"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 300000000
#     }
#     word: "new"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 500000000
#     }
#     word: "key"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 600000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 900000000
#     }
#     word: "work"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 900000000
#     }
#     word: "OBS"
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 31
#       nanos: 200000000
#     }
#     word: "users"
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 31
#       nanos: 400000000
#     }
#     word: "who"
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 31
#       nanos: 800000000
#     }
#     word: "connected"
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 31
#       nanos: 900000000
#     }
#     word: "their"
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 32
#       nanos: 100000000
#     }
#     word: "Twitter"
#   }
#   words {
#     start_time {
#       seconds: 32
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 32
#       nanos: 400000000
#     }
#     word: "account."
#   }
#   words {
#     start_time {
#       seconds: 32
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 32
#       nanos: 600000000
#     }
#     word: "Should"
#   }
#   words {
#     start_time {
#       seconds: 32
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 32
#       nanos: 800000000
#     }
#     word: "also"
#   }
#   words {
#     start_time {
#       seconds: 32
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 33
#     }
#     word: "not"
#   }
#   words {
#     start_time {
#       seconds: 33
#     }
#     end_time {
#       seconds: 33
#       nanos: 200000000
#     }
#     word: "need"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 33
#       nanos: 300000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 33
#       nanos: 500000000
#     }
#     word: "take"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 33
#       nanos: 700000000
#     }
#     word: "any"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 33
#       nanos: 800000000
#     }
#     word: "action"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 35
#     }
#     word: "lbs"
#   }
#   words {
#     start_time {
#       seconds: 35
#     }
#     end_time {
#       seconds: 35
#       nanos: 300000000
#     }
#     word: "users"
#   }
#   words {
#     start_time {
#       seconds: 35
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 35
#       nanos: 500000000
#     }
#     word: "that"
#   }
#   words {
#     start_time {
#       seconds: 35
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 35
#       nanos: 600000000
#     }
#     word: "if"
#   }
#   words {
#     start_time {
#       seconds: 35
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 35
#       nanos: 800000000
#     }
#     word: "not"
#   }
#   words {
#     start_time {
#       seconds: 35
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 36
#       nanos: 500000000
#     }
#     word: "connected"
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 36
#       nanos: 600000000
#     }
#     word: "their"
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 36
#       nanos: 800000000
#     }
#     word: "Twitter"
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 37
#       nanos: 100000000
#     }
#     word: "account."
#   }
#   words {
#     start_time {
#       seconds: 37
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 37
#       nanos: 600000000
#     }
#     word: "OBS"
#   }
#   words {
#     start_time {
#       seconds: 37
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 37
#       nanos: 800000000
#     }
#     word: "will"
#   }
#   words {
#     start_time {
#       seconds: 37
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 37
#       nanos: 900000000
#     }
#     word: "need"
#   }
#   words {
#     start_time {
#       seconds: 37
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 38
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 38
#     }
#     end_time {
#       seconds: 38
#       nanos: 400000000
#     }
#     word: "manually"
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 600000000
#     }
#     word: "copy"
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 800000000
#     }
#     word: "their"
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 100000000
#     }
#     word: "string"
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 200000000
#     }
#     word: "key"
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 400000000
#     }
#     word: "for"
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 600000000
#     }
#     word: "their"
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 900000000
#     }
#     word: "twitch"
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 200000000
#     }
#     word: "dashboard"
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 500000000
#     }
#     word: "and"
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 800000000
#     }
#     word: "paste"
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 900000000
#     }
#     word: "it"
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 41
#     }
#     word: "into"
#   }
#   words {
#     start_time {
#       seconds: 41
#     }
#     end_time {
#       seconds: 41
#       nanos: 500000000
#     }
#     word: "OBS,"
#   }
#   words {
#     start_time {
#       seconds: 41
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 200000000
#     }
#     word: "for"
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 400000000
#     }
#     word: "all"
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 700000000
#     }
#     word: "others."
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 900000000
#     }
#     word: "Please"
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 43
#       nanos: 200000000
#     }
#     word: "refer"
#   }
#   words {
#     start_time {
#       seconds: 43
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 43
#       nanos: 400000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 43
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 43
#       nanos: 700000000
#     }
#     word: "specific,"
#   }
#   words {
#     start_time {
#       seconds: 43
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 44
#       nanos: 300000000
#     }
#     word: "set"
#   }
#   words {
#     start_time {
#       seconds: 44
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 44
#       nanos: 400000000
#     }
#     word: "up"
#   }
#   words {
#     start_time {
#       seconds: 44
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 44
#       nanos: 700000000
#     }
#     word: "instructions"
#   }
#   words {
#     start_time {
#       seconds: 44
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 45
#       nanos: 100000000
#     }
#     word: "for"
#   }
#   words {
#     start_time {
#       seconds: 45
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 45
#       nanos: 300000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 45
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 45
#       nanos: 600000000
#     }
#     word: "software"
#   }
#   words {
#     start_time {
#       seconds: 45
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 46
#       nanos: 200000000
#     }
#     word: "virtuous,"
#   }
#   words {
#     start_time {
#       seconds: 46
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 46
#       nanos: 800000000
#     }
#     word: "and"
#   }
#   words {
#     start_time {
#       seconds: 46
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 47
#     }
#     word: "there\'s"
#   }
#   words {
#     start_time {
#       seconds: 47
#     }
#     end_time {
#       seconds: 47
#       nanos: 100000000
#     }
#     word: "an"
#   }
#   words {
#     start_time {
#       seconds: 47
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 47
#       nanos: 400000000
#     }
#     word: "update"
#   }
#   words {
#     start_time {
#       seconds: 47
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 48
#     }
#     word: "late"
#   }
#   words {
#     start_time {
#       seconds: 48
#     }
#     end_time {
#       seconds: 48
#       nanos: 200000000
#     }
#     word: "on"
#   }
#   words {
#     start_time {
#       seconds: 48
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 48
#       nanos: 300000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 48
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 48
#       nanos: 600000000
#     }
#     word: "night"
#   }
#   words {
#     start_time {
#       seconds: 48
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 48
#       nanos: 800000000
#     }
#     word: "of"
#   }
#   words {
#     start_time {
#       seconds: 48
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 49
#       nanos: 500000000
#     }
#     word: "October"
#   }
#   words {
#     start_time {
#       seconds: 49
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 50
#       nanos: 300000000
#     }
#     word: "6th"
#   }
#   words {
#     start_time {
#       seconds: 50
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 51
#       nanos: 200000000
#     }
#     word: "2021"
#   }
#   words {
#     start_time {
#       seconds: 51
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 51
#       nanos: 200000000
#     }
#     word: "at"
#   }
#   words {
#     start_time {
#       seconds: 51
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 51
#       nanos: 800000000
#     }
#     word: "10:30"
#   }
#   words {
#     start_time {
#       seconds: 51
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 51
#       nanos: 900000000
#     }
#     word: "p.m."
#   }
#   words {
#     start_time {
#       seconds: 51
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 52
#       nanos: 500000000
#     }
#     word: "Pacific"
#   }
#   words {
#     start_time {
#       seconds: 52
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 52
#       nanos: 900000000
#     }
#     word: "time."
#   }
#   words {
#     start_time {
#       seconds: 52
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 54
#     }
#     word: "We\'ve"
#   }
#   words {
#     start_time {
#       seconds: 54
#     }
#     end_time {
#       seconds: 54
#       nanos: 400000000
#     }
#     word: "learned"
#   }
#   words {
#     start_time {
#       seconds: 54
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 54
#       nanos: 400000000
#     }
#     word: "that"
#   }
#   words {
#     start_time {
#       seconds: 54
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 54
#       nanos: 800000000
#     }
#     word: "some"
#   }
#   words {
#     start_time {
#       seconds: 54
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 100000000
#     }
#     word: "data"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 200000000
#     }
#     word: "was"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 700000000
#     }
#     word: "exposed"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 700000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 900000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 56
#       nanos: 300000000
#     }
#     word: "internet"
#   }
#   words {
#     start_time {
#       seconds: 56
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 56
#       nanos: 700000000
#     }
#     word: "due"
#   }
#   words {
#     start_time {
#       seconds: 56
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 56
#       nanos: 900000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 56
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 57
#     }
#     word: "an"
#   }
#   words {
#     start_time {
#       seconds: 57
#     }
#     end_time {
#       seconds: 57
#       nanos: 300000000
#     }
#     word: "error"
#   }
#   words {
#     start_time {
#       seconds: 57
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 57
#       nanos: 600000000
#     }
#     word: "in"
#   }
#   words {
#     start_time {
#       seconds: 57
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 57
#       nanos: 700000000
#     }
#     word: "at"
#   }
#   words {
#     start_time {
#       seconds: 57
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 57
#       nanos: 900000000
#     }
#     word: "which"
#   }
#   words {
#     start_time {
#       seconds: 57
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 58
#       nanos: 300000000
#     }
#     word: "server"
#   }
#   words {
#     start_time {
#       seconds: 58
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 58
#       nanos: 900000000
#     }
#     word: "configuration"
#   }
#   words {
#     start_time {
#       seconds: 58
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 59
#       nanos: 500000000
#     }
#     word: "change."
#   }
#   words {
#     start_time {
#       seconds: 59
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 59
#       nanos: 700000000
#     }
#     word: "That"
#   }
#   words {
#     start_time {
#       seconds: 59
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 59
#       nanos: 800000000
#     }
#     word: "was"
#   }
#   words {
#     start_time {
#       seconds: 59
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 60
#       nanos: 300000000
#     }
#     word: "subsequently"
#   }
#   words {
#     start_time {
#       seconds: 60
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 61
#     }
#     word: "accessed"
#   }
#   words {
#     start_time {
#       seconds: 61
#     }
#     end_time {
#       seconds: 61
#       nanos: 400000000
#     }
#     word: "by"
#   }
#   words {
#     start_time {
#       seconds: 61
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 61
#       nanos: 600000000
#     }
#     word: "them."
#   }
# }
# language_code: "en-us"
# , alternatives {
#   transcript: "Malicious third-party, our teams are working with urgency to investigate the incident as the investigation is ongoing. We are still in the process of understanding. The impact in detail when to stand at this situation, raises concerns, and we want to address some of those here while our investigation continues at this time. We have no indication that, login credentials have been exposed. We are continuing to investigate, additionally"
#   confidence: 0.9600023
#   words {
#     start_time {
#       seconds: 61
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 62
#       nanos: 100000000
#     }
#     word: "Malicious"
#   }
#   words {
#     start_time {
#       seconds: 62
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 63
#       nanos: 100000000
#     }
#     word: "third-party,"
#   }
#   words {
#     start_time {
#       seconds: 63
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 63
#       nanos: 600000000
#     }
#     word: "our"
#   }
#   words {
#     start_time {
#       seconds: 63
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 63
#       nanos: 900000000
#     }
#     word: "teams"
#   }
#   words {
#     start_time {
#       seconds: 63
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 64
#     }
#     word: "are"
#   }
#   words {
#     start_time {
#       seconds: 64
#     }
#     end_time {
#       seconds: 64
#       nanos: 200000000
#     }
#     word: "working"
#   }
#   words {
#     start_time {
#       seconds: 64
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 64
#       nanos: 500000000
#     }
#     word: "with"
#   }
#   words {
#     start_time {
#       seconds: 64
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 64
#       nanos: 900000000
#     }
#     word: "urgency"
#   }
#   words {
#     start_time {
#       seconds: 64
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 65
#       nanos: 200000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 65
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 65
#       nanos: 800000000
#     }
#     word: "investigate"
#   }
#   words {
#     start_time {
#       seconds: 65
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 65
#       nanos: 900000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 65
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 66
#       nanos: 500000000
#     }
#     word: "incident"
#   }
#   words {
#     start_time {
#       seconds: 66
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 67
#       nanos: 200000000
#     }
#     word: "as"
#   }
#   words {
#     start_time {
#       seconds: 67
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 67
#       nanos: 300000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 67
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 67
#       nanos: 900000000
#     }
#     word: "investigation"
#   }
#   words {
#     start_time {
#       seconds: 67
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 68
#     }
#     word: "is"
#   }
#   words {
#     start_time {
#       seconds: 68
#     }
#     end_time {
#       seconds: 68
#       nanos: 200000000
#     }
#     word: "ongoing."
#   }
#   words {
#     start_time {
#       seconds: 68
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 68
#       nanos: 900000000
#     }
#     word: "We"
#   }
#   words {
#     start_time {
#       seconds: 68
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 69
#     }
#     word: "are"
#   }
#   words {
#     start_time {
#       seconds: 69
#     }
#     end_time {
#       seconds: 69
#       nanos: 200000000
#     }
#     word: "still"
#   }
#   words {
#     start_time {
#       seconds: 69
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 69
#       nanos: 300000000
#     }
#     word: "in"
#   }
#   words {
#     start_time {
#       seconds: 69
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 69
#       nanos: 400000000
#     }
#     word: "the"
#   }
#   words {
#     start_time {
#       seconds: 69
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 69
#       nanos: 500000000
#     }
#     word: "process"
#   }
#   words {
#     start_time {
#       seconds: 69
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 69
#       nanos: 800000000
#     }
#     word: "of"
#   }
#   words {
#     start_time {
#       seconds: 69
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 70
#       nanos: 100000000
#     }
#     word: "understanding."
#   }
#   words {
#     start_time {
#       seconds: 70
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 70
#       nanos: 700000000
#     }
#     word: "The"
#   }
#   words {
#     start_time {
#       seconds: 70
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 71
#     }
#     word: "impact"
#   }
#   words {
#     start_time {
#       seconds: 71
#     }
#     end_time {
#       seconds: 71
#       nanos: 300000000
#     }
#     word: "in"
#   }
#   words {
#     start_time {
#       seconds: 71
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 71
#       nanos: 700000000
#     }
#     word: "detail"
#   }
#   words {
#     start_time {
#       seconds: 71
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 72
#       nanos: 200000000
#     }
#     word: "when"
#   }
#   words {
#     start_time {
#       seconds: 72
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 72
#       nanos: 400000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 72
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 72
#       nanos: 700000000
#     }
#     word: "stand"
#   }
#   words {
#     start_time {
#       seconds: 72
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 72
#       nanos: 800000000
#     }
#     word: "at"
#   }
#   words {
#     start_time {
#       seconds: 72
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 73
#     }
#     word: "this"
#   }
#   words {
#     start_time {
#       seconds: 73
#     }
#     end_time {
#       seconds: 73
#       nanos: 300000000
#     }
#     word: "situation,"
#   }
#   words {
#     start_time {
#       seconds: 73
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 73
#       nanos: 800000000
#     }
#     word: "raises"
#   }
#   words {
#     start_time {
#       seconds: 73
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 74
#       nanos: 500000000
#     }
#     word: "concerns,"
#   }
#   words {
#     start_time {
#       seconds: 74
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 74
#       nanos: 600000000
#     }
#     word: "and"
#   }
#   words {
#     start_time {
#       seconds: 74
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 74
#       nanos: 700000000
#     }
#     word: "we"
#   }
#   words {
#     start_time {
#       seconds: 74
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 74
#       nanos: 900000000
#     }
#     word: "want"
#   }
#   words {
#     start_time {
#       seconds: 74
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 75
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 75
#     }
#     end_time {
#       seconds: 75
#       nanos: 300000000
#     }
#     word: "address"
#   }
#   words {
#     start_time {
#       seconds: 75
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 75
#       nanos: 900000000
#     }
#     word: "some"
#   }
#   words {
#     start_time {
#       seconds: 75
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 76
#     }
#     word: "of"
#   }
#   words {
#     start_time {
#       seconds: 76
#     }
#     end_time {
#       seconds: 76
#       nanos: 300000000
#     }
#     word: "those"
#   }
#   words {
#     start_time {
#       seconds: 76
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 76
#       nanos: 700000000
#     }
#     word: "here"
#   }
#   words {
#     start_time {
#       seconds: 76
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 77
#       nanos: 300000000
#     }
#     word: "while"
#   }
#   words {
#     start_time {
#       seconds: 77
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 77
#       nanos: 300000000
#     }
#     word: "our"
#   }
#   words {
#     start_time {
#       seconds: 77
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 78
#       nanos: 100000000
#     }
#     word: "investigation"
#   }
#   words {
#     start_time {
#       seconds: 78
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 78
#       nanos: 600000000
#     }
#     word: "continues"
#   }
#   words {
#     start_time {
#       seconds: 78
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 79
#       nanos: 300000000
#     }
#     word: "at"
#   }
#   words {
#     start_time {
#       seconds: 79
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 79
#       nanos: 400000000
#     }
#     word: "this"
#   }
#   words {
#     start_time {
#       seconds: 79
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 79
#       nanos: 900000000
#     }
#     word: "time."
#   }
#   words {
#     start_time {
#       seconds: 79
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 80
#       nanos: 200000000
#     }
#     word: "We"
#   }
#   words {
#     start_time {
#       seconds: 80
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 80
#       nanos: 300000000
#     }
#     word: "have"
#   }
#   words {
#     start_time {
#       seconds: 80
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 80
#       nanos: 900000000
#     }
#     word: "no"
#   }
#   words {
#     start_time {
#       seconds: 80
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 81
#       nanos: 200000000
#     }
#     word: "indication"
#   }
#   words {
#     start_time {
#       seconds: 81
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 81
#       nanos: 800000000
#     }
#     word: "that,"
#   }
#   words {
#     start_time {
#       seconds: 81
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 82
#       nanos: 200000000
#     }
#     word: "login"
#   }
#   words {
#     start_time {
#       seconds: 82
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 82
#       nanos: 600000000
#     }
#     word: "credentials"
#   }
#   words {
#     start_time {
#       seconds: 82
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 82
#       nanos: 800000000
#     }
#     word: "have"
#   }
#   words {
#     start_time {
#       seconds: 82
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 82
#       nanos: 900000000
#     }
#     word: "been"
#   }
#   words {
#     start_time {
#       seconds: 82
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 83
#       nanos: 300000000
#     }
#     word: "exposed."
#   }
#   words {
#     start_time {
#       seconds: 83
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 84
#     }
#     word: "We"
#   }
#   words {
#     start_time {
#       seconds: 84
#     }
#     end_time {
#       seconds: 84
#       nanos: 100000000
#     }
#     word: "are"
#   }
#   words {
#     start_time {
#       seconds: 84
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 84
#       nanos: 900000000
#     }
#     word: "continuing"
#   }
#   words {
#     start_time {
#       seconds: 84
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 85
#       nanos: 200000000
#     }
#     word: "to"
#   }
#   words {
#     start_time {
#       seconds: 85
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 86
#       nanos: 100000000
#     }
#     word: "investigate,"
#   }
#   words {
#     start_time {
#       seconds: 86
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 87
#       nanos: 400000000
#     }
#     word: "additionally"
#   }
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " Full credit card information. Credit card numbers are not stored by twitch. So, full credit card numbers were not exposed and then conveniently a, they have a section called in other news and September 29th, securing your chat with phone an e-mail verification. And this is an article about hate and harassment and that which did not have a good day yesterday. That was a big leak. Let\'s talk about this article from The Verge Twitches, security problems. Started long before this week\'s hack, subtitled bad security practices, made the breach seemed inevitable, two former employees, a massive security breach at, which has exposed the wealth of information pertaining to the website source code, unreleased projects and even how much, the top streamers make is data analysts and journalists were to decipher. What is exactly contained in the hundreds of gigabytes of information, others are still wondering how this happened. Such a breach, seems like it was increasingly likely to some, the verge of spoken to multiple sources, who claim that during their time at 2."
#   confidence: 0.96947867
#   words {
#     start_time {
#       seconds: 88
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 89
#     }
#     word: "Full"
#   }
#   words {
#     start_time {
#       seconds: 89
#     }
#     end_time {
#       seconds: 89
#       nanos: 300000000
#     }
#     word: "credit"
#   }
#   words {
#     start_time {
#       seconds: 89
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 89
#       nanos: 500000000
#     }
#     word: "card"
#   }
#   words {
#     start_time {
#       seconds: 89
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 89
#       nanos: 700000000
#     }
#     word: "information."
#   }
#   words {
#     start_time {
#       seconds: 89
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 90
#       nanos: 700000000
#     }
#     word: "Credit"
#   }
#   words {
#     start_time {
#       seconds: 90
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 90
#       nanos: 900000000
#     }
#     word: "card"
#   }
#   words {
#     start_time {
#       seconds: 90
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 91
#       nanos: 200000000
#     }
#     word: "numbers"
#   }
#   words {
#     start_time {
#       seconds: 91
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 91
#       nanos: 200000000
#     }
#     word: "are"
#   }
#   words {
#     start_time {
#       seconds: 91
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 91
#       nanos: 500000000
#     }
#     word: "not"
#   }
#   words {
#     start_time {
#       seconds: 91
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 91
#       nanos: 700000000
#     }
#     word: "stored"
#   }
#   words {
#     start_time {
#       seconds: 91
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 91
#       nanos: 800000000
#     }
#     word: "by"
#   }
#   words {
#     start_time {
#       seconds: 91
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 92
#       nanos: 100000000
#     }
#     word: "twitch."
#   }
#   words {
#     start_time {
#       seconds: 92
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 92
#       nanos: 300000000
#     }
#     word: "So,"
#   }
#   words {
#     start_time {
#       seconds: 92
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 92
#       nanos: 600000000
#     }
#     word: "full"
#   }
#   words {
#     start_time {
#       seconds: 92
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 92
#       nanos: 900000000
#     }
#     word: "credit"
#   }
#   words {
#     start_time {
#       seconds: 92
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 93
#     }
#     word: "card"
#   }
#   words {
#     start_time {
#       seconds: 93
#     }
#     end_time {
#       seconds: 93
#       nanos: 400000000
#     }
#     word: "numbers"
#   }
#   words {
#     start_time {
#       seconds: 93
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 93
#       nanos: 600000000
#     }
#     word: "were"
#   }
#   words {
#     start_time {
#       seconds: 93
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 93
#       nanos: 700000000
#     }
#     word: "not"
#   }
#   words {
#     start_time {
#       seconds: 93
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 94
#       nanos: 400000000
#     }
#     word: "exposed"
#   }
#   words {
#     start_time {
#       seconds: 94
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 95
#       nanos: 300000000
#     }
#     word: "and"
#   }
#   words {
#     start_time {
#       seconds: 95
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 95
#       nanos: 500000000
#     }
#     word: "then"
#   }
#   words {
#     start_time {
#       seconds: 95
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 95
#       nanos: 900000000
#     }
#     word: "conveniently"
#   }
#   words {
#     start_time {
#       seconds: 95
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 96
#       nanos: 300000000
#     }
#     word: "a,"
#   }
#   words {
#     start_time {
#       seconds: 96
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 96
#       nanos: 600000000
#     }
#     word: "they"
#   }
#   words {
#     start_time {
#       seconds: 96
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 96
#       nanos: 700000000
#     }
#     word: "have"
#   }
#   words {
#     start_time {
#       seconds: 96
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 96
#       nanos: 800000000
#     }
#     word: "a"
#   }
#   words {
#     start_time {
#       seconds: 96
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 97
#       nanos: 100000000
#     }
#     word: "section"
#   }
#   words {
#     start_time {
#       seconds: 97
#       nanos: 100000000
#     }
# ...
#     word: "alarms"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 201
#     }
#     end_time {
#       seconds: 201
#       nanos: 100000000
#     }
#     word: "were"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 201
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 201
#       nanos: 400000000
#     }
#     word: "raised"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 201
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 201
#       nanos: 500000000
#     }
#     word: "about"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 201
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 201
#       nanos: 600000000
#     }
#     word: "the"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 201
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 202
#     }
#     word: "potential"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 202
#     }
#     end_time {
#       seconds: 202
#       nanos: 200000000
#     }
#     word: "abuses"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 202
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 202
#       nanos: 600000000
#     }
#     word: "of"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 202
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 202
#       nanos: 900000000
#     }
#     word: "raids"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 202
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 203
#       nanos: 200000000
#     }
#     word: "long"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 203
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 203
#       nanos: 500000000
#     }
#     word: "before"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 203
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 203
#       nanos: 700000000
#     }
#     word: "their"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 203
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 204
#     }
#     word: "hate"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 204
#     }
#     end_time {
#       seconds: 204
#       nanos: 500000000
#     }
#     word: "variety"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 204
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 204
#       nanos: 900000000
#     }
#     word: "exploded"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 204
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 205
#     }
#     word: "in"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 205
#     }
#     end_time {
#       seconds: 205
#       nanos: 500000000
#     }
#     word: "August."
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 205
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 206
#       nanos: 400000000
#     }
#     word: "One"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 206
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 206
#       nanos: 700000000
#     }
#     word: "Source"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 206
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 206
#       nanos: 800000000
#     }
#     word: "who"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 206
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 206
#       nanos: 900000000
#     }
#     word: "spoke"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 206
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 207
#       nanos: 100000000
#     }
#     word: "to"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 207
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 207
#       nanos: 200000000
#     }
#     word: "the"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 207
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 207
#       nanos: 600000000
#     }
#     word: "verge"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 207
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 207
#       nanos: 700000000
#     }
#     word: "on"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 207
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 207
#       nanos: 800000000
#     }
#     word: "the"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 207
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 208
#     }
#     word: "condition"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 208
#     }
#     end_time {
#       seconds: 208
#       nanos: 200000000
#     }
#     word: "of"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 208
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 208
#       nanos: 300000000
#     }
#     word: "anonymity"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 208
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 209
#       nanos: 300000000
#     }
#     word: "worked"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 209
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 209
#       nanos: 400000000
#     }
#     word: "at"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 209
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 209
#       nanos: 600000000
#     }
#     word: "which,"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 209
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 209
#       nanos: 800000000
#     }
#     word: "from"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 209
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 210
#       nanos: 500000000
#     }
#     word: "2017"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 210
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 210
#       nanos: 600000000
#     }
#     word: "to"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 210
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 211
#       nanos: 300000000
#     }
#     word: "2019."
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 211
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 211
#       nanos: 800000000
#     }
#     word: "They"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 211
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 212
#       nanos: 200000000
#     }
#     word: "described"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 212
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 212
#       nanos: 300000000
#     }
#     word: "an"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 212
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 212
#       nanos: 700000000
#     }
#     word: "atmosphere"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 212
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 212
#       nanos: 900000000
#     }
#     word: "where"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 212
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 213
#       nanos: 300000000
#     }
#     word: "employees"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 213
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 213
#       nanos: 500000000
#     }
#     word: "were"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 213
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 213
#       nanos: 500000000
#     }
#     word: "very"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 213
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 214
#     }
#     word: "concerned"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 214
#     }
#     end_time {
#       seconds: 214
#       nanos: 200000000
#     }
#     word: "about"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 214
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 214
#       nanos: 600000000
#     }
#     word: "safety"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 214
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 214
#       nanos: 900000000
#     }
#     word: "but"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 214
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 215
#       nanos: 200000000
#     }
#     word: "management"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 215
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 215
#       nanos: 600000000
#     }
#     word: "less."
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 215
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 215
#       nanos: 700000000
#     }
#     word: "So"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 215
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 216
#       nanos: 400000000
#     }
#     word: "than"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 216
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 216
#       nanos: 400000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 216
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 216
#       nanos: 700000000
#     }
#     word: "article"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 216
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 217
#     }
#     word: "continues"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 217
#     }
#     end_time {
#       seconds: 217
#       nanos: 500000000
#     }
#     word: "and"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 217
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 217
#       nanos: 600000000
#     }
#     word: "continues"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 217
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 218
#       nanos: 200000000
#     }
#     word: "to,"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 218
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 218
#       nanos: 400000000
#     }
#     word: "which"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 218
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 218
#       nanos: 700000000
#     }
#     word: "has"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 218
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 218
#       nanos: 900000000
#     }
#     word: "not"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 218
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 219
#       nanos: 100000000
#     }
#     word: "been"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 219
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 219
#       nanos: 200000000
#     }
#     word: "having"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 219
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 219
#       nanos: 400000000
#     }
#     word: "a"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 219
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 219
#       nanos: 500000000
#     }
#     word: "great"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 219
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 220
#     }
#     word: "weekend,"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 220
#     }
#     end_time {
#       seconds: 220
#       nanos: 100000000
#     }
#     word: "is"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 220
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 220
#       nanos: 300000000
#     }
#     word: "not"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 220
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 220
#       nanos: 600000000
#     }
#     word: "uncommon,"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 220
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 221
#       nanos: 200000000
#     }
#     word: "post"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 221
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 221
#       nanos: 400000000
#     }
#     word: "breach"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 221
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 222
#     }
#     word: "or"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 222
#     }
#     end_time {
#       seconds: 222
#       nanos: 400000000
#     }
#     word: "companies"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 222
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 222
#       nanos: 600000000
#     }
#     word: "get"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 222
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 222
#       nanos: 800000000
#     }
#     word: "a"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 222
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 223
#       nanos: 100000000
#     }
#     word: "closer"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 223
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 223
#       nanos: 500000000
#     }
#     word: "or"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 223
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 223
#       nanos: 800000000
#     }
#     word: "deeper"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 223
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 224
#     }
#     word: "examination"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 224
#     }
#     end_time {
#       seconds: 224
#       nanos: 700000000
#     }
#     word: "of"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 224
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 224
#       nanos: 700000000
#     }
#     word: "their"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 224
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 225
#     }
#     word: "practices,"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 225
#     }
#     end_time {
#       seconds: 225
#       nanos: 800000000
#     }
#     word: "and"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 225
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 226
#       nanos: 100000000
#     }
#     word: "some"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 226
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 226
#       nanos: 400000000
#     }
#     word: "things"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 226
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 226
#       nanos: 500000000
#     }
#     word: "that"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 226
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 226
#       nanos: 600000000
#     }
#     word: "they"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 226
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 226
#       nanos: 800000000
#     }
#     word: "may"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 226
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 226
#       nanos: 900000000
#     }
#     word: "not"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 226
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 227
#       nanos: 100000000
#     }
#     word: "want"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 227
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 227
#       nanos: 700000000
#     }
#     word: "come"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 227
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 227
#       nanos: 800000000
#     }
#     word: "to"
#     speaker_tag: 2
#   }
#   words {
#     start_time {
#       seconds: 227
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 228
#     }
#     word: "light."
#     speaker_tag: 2
#   }
# }
# ]

# %%
def parse_transcription_results(results):
    """
    Parse the transcription results
    """
    full_text = ""
    timing_text = []
    segments = []
    running_time_in_ms = 0
    for result in results:
        full_text += "\n{}".format(result.alternatives[0].transcript)
        timing = []
        for word in result.alternatives[0].words:
            time_start_in_ms = (word.start_time.seconds * 1000) + (word.start_time.microseconds / 1000)
            time_finish_in_ms = (word.end_time.seconds * 1000) + (word.end_time.microseconds / 1000)
            timecode_start = get_timecode(time_start_in_ms)
            timecode_finish = get_timecode(time_finish_in_ms)

            w = {
                'word': word.word,
                'timecode_start': timecode_start,
                'timecode_finish': timecode_finish,
                'timecode_start_as_ms': time_start_in_ms,
                'timecode_finish_as_ms': time_finish_in_ms,
                'duration_as_ms': int(time_finish_in_ms - time_start_in_ms),
                }

            timing_text.append(w)
            segments.append({
                "text": result.alternatives[0].transcript,
                "confidence": result.alternatives[0].confidence,
                "timing": w,
                })

    return {
        "full_text": full_text,
        "segments": segments,
        "timing": timing_text,
        }

def get_timecode(time_in_ms):
    # Figure out the timestamp
    sec_as_ms = 1000
    min_as_ms = 60*sec_as_ms
    hr_as_ms = 60*min_as_ms

    remaining = time_in_ms

    hours = int(remaining / hr_as_ms)
    remaining = remaining - (hours * hr_as_ms)

    minutes = int(remaining / min_as_ms)
    remaining = remaining - (minutes * min_as_ms)

    seconds = int(remaining / sec_as_ms)
    remaining = remaining - (seconds * sec_as_ms)

    ms = abs(int(remaining))

    return "{:02d}:{:02d}:{:02d},{:03d}".format(hours, minutes, seconds, ms)

# %%
structured_results = parse_transcription_results(results)

# %%
print(structured_results['timing'][1])
# Out:
# {'word': 'is', 'timecode_start': '00:00:02,100', 'timecode_finish': '00:00:02,200', 'timecode_start_as_ms': 2100.0, 'timecode_finish_as_ms': 2200.0, 'duration_as_ms': 100}

# %%
def generate_srt(word_timing, line_size=35):
    """
    Generate the SRT file from a list of words and their timings
    """
    # NN
    # TIMECODE --> TIMECODE
    # WWW WWW WWW

    # check for a restart in the word timings
    starts_at = 0
    first_entry = { 'word': word_timing[0]['word'], 'timecode_start_as_ms': word_timing[0]['timecode_start_as_ms'] }
    for i, w in enumerate(word_timing):
        if (w['word'] == first_entry['word'] and w['timecode_start_as_ms'] == first_entry['timecode_start_as_ms']) or (int(w['timecode_start_as_ms']) < 1):
            starts_at = i

    srt = ""
    caption = 1
    current_entry = {'words': "", 'start': None, 'finish': None }
    for i, word in enumerate(word_timing):
        if i < starts_at: continue
        if not current_entry['start']: current_entry['start'] = word['timecode_start']
        if len(current_entry['words']) > line_size or i >= len(word_timing):
            # print the entry
            srt += "{}\n{} --> {}\n{}\n\n".format(caption, current_entry['start'], current_entry['finish'], current_entry['words'].strip())
            caption += 1
            current_entry = {'words': "", 'start': word['timecode_start'], 'finish': None }

        current_entry['words'] += " {}".format(word['word'])
        current_entry['finish'] = word['timecode_finish']

    srt += "{}\n{} --> {}\n{}\n\n".format(caption, current_entry['start'], current_entry['finish'], current_entry['words'].strip())		

    return srt

# %%
print(generate_srt(structured_results['timing'], line_size=35))
# Out:
# 1
# 00:00:01,600 --> 00:00:03,700
# This is from an article called updates
#
# 2
# 00:00:03,700 --> 00:00:05,500
# on the twitch security. Incident posted
#
# 3
# 00:00:05,500 --> 00:00:08,100
# to the twitch blog on October 6th, 2021
#
# 4
# 00:00:08,100 --> 00:00:11,200
# update regarding stream keys out of
#
# 5
# 00:00:11,200 --> 00:00:13,500
# an abundance of caution. We have reset
#
# 6
# 00:00:13,500 --> 00:00:15,300
# all stream key so you can get your new
#
# 7
# 00:00:15,300 --> 00:00:17,200
# stream key here. Then it listen to around,
#
# 8
# 00:00:17,200 --> 00:00:19,200
# depending on which broadcast offer you
#
# 9
# 00:00:19,200 --> 00:00:20,500
# use. You may need to manually update
#
# 10
# 00:00:20,500 --> 00:00:22,400
# yourself, or with this new key to start
#
# 11
# 00:00:22,400 --> 00:00:25,100
# your next stream. Twitch Studio streamlabs
#
# 12
# 00:00:25,100 --> 00:00:26,700
# Xbox PlayStation, and twitch mobile
#
# 13
# 00:00:26,700 --> 00:00:28,600
# app users. Do not need to take any action
#
# 14
# 00:00:28,600 --> 00:00:31,400
# for your new key to work OBS users who
#
# 15
# 00:00:31,400 --> 00:00:32,600
# connected their Twitter account. Should
#
# 16
# 00:00:32,600 --> 00:00:35,000
# also not need to take any action lbs
#
# 17
# 00:00:35,000 --> 00:00:36,800
# users that if not connected their Twitter
#
# 18
# 00:00:36,800 --> 00:00:38,600
# account. OBS will need to manually copy
#
# 19
# 00:00:38,600 --> 00:00:40,200
# their string key for their twitch dashboard
#
# 20
# 00:00:40,200 --> 00:00:42,700
# and paste it into OBS, for all others.
#
# 21
# 00:00:42,700 --> 00:00:44,700
# Please refer to specific, set up instructions
#
# 22
# 00:00:44,700 --> 00:00:47,000
# for the software virtuous, and there's
#
# 23
# 00:00:47,000 --> 00:00:49,500
# an update late on the night of October
#
# 24
# 00:00:49,500 --> 00:00:52,900
# 6th 2021 at 10:30 p.m. Pacific time.
#
# 25
# 00:00:52,900 --> 00:00:55,700
# We've learned that some data was exposed
#
# 26
# 00:00:55,700 --> 00:00:57,700
# to the internet due to an error in at
#
# 27
# 00:00:57,700 --> 00:00:59,700
# which server configuration change. That
#
# 28
# 00:00:59,700 --> 00:01:02,100
# was subsequently accessed by them. Malicious
#
# 29
# 00:01:02,100 --> 00:01:04,500
# third-party, our teams are working with
#
# 30
# 00:01:04,500 --> 00:01:06,500
# urgency to investigate the incident
#
# 31
# 00:01:06,500 --> 00:01:08,900
# as the investigation is ongoing. We
#
# 32
# 00:01:08,900 --> 00:01:10,100
# are still in the process of understanding.
#
# 33
# 00:01:10,100 --> 00:01:12,800
# The impact in detail when to stand at
#
# 34
# 00:01:12,800 --> 00:01:14,600
# this situation, raises concerns, and
#
# 35
# 00:01:14,600 --> 00:01:16,700
# we want to address some of those here
#
# 36
# 00:01:16,700 --> 00:01:19,300
# while our investigation continues at
#
# 37
# 00:01:19,300 --> 00:01:21,800
# this time. We have no indication that,
#
# 38
# 00:01:21,800 --> 00:01:23,300
# login credentials have been exposed.
#
# 39
# 00:01:23,300 --> 00:01:27,400
# We are continuing to investigate, additionally
#
# 40
# 00:01:28,500 --> 00:01:30,700
# Full credit card information. Credit
#
# 41
# 00:01:30,700 --> 00:01:32,100
# card numbers are not stored by twitch.
#
# 42
# 00:01:32,100 --> 00:01:33,700
# So, full credit card numbers were not
#
# 43
# 00:01:33,700 --> 00:01:36,600
# exposed and then conveniently a, they
#
# 44
# 00:01:36,600 --> 00:01:37,800
# have a section called in other news
#
# 45
# 00:01:37,800 --> 00:01:41,000
# and September 29th, securing your chat
#
# 46
# 00:01:41,000 --> 00:01:43,800
# with phone an e-mail verification. And
#
# 47
# 00:01:43,800 --> 00:01:45,800
# this is an article about hate and harassment
#
# 48
# 00:01:45,800 --> 00:01:48,600
# and that which did not have a good day
#
# 49
# 00:01:48,600 --> 00:01:53,200
# yesterday. That was a big leak. Let's
#
# 50
# 00:01:53,200 --> 00:01:55,500
# talk about this article from The Verge
#
# 51
# 00:01:55,500 --> 00:01:57,300
# Twitches, security problems. Started
#
# 52
# 00:01:57,300 --> 00:02:00,400
# long before this week's hack, subtitled
#
# 53
# 00:02:00,400 --> 00:02:02,700
# bad security practices, made the breach
#
# 54
# 00:02:02,700 --> 00:02:04,200
# seemed inevitable, two former employees,
#
# 55
# 00:02:04,200 --> 00:02:07,200
# a massive security breach at, which
#
# 56
# 00:02:07,200 --> 00:02:08,400
# has exposed the wealth of information
#
# 57
# 00:02:08,400 --> 00:02:10,500
# pertaining to the website source code,
#
# 58
# 00:02:10,500 --> 00:02:12,200
# unreleased projects and even how much,
#
# 59
# 00:02:12,200 --> 00:02:14,600
# the top streamers make is data analysts
#
# 60
# 00:02:14,600 --> 00:02:16,100
# and journalists were to decipher. What
#
# 61
# 00:02:16,100 --> 00:02:17,700
# is exactly contained in the hundreds
#
# 62
# 00:02:17,700 --> 00:02:19,500
# of gigabytes of information, others
#
# 63
# 00:02:19,500 --> 00:02:21,600
# are still wondering how this happened.
#
# 64
# 00:02:21,600 --> 00:02:23,700
# Such a breach, seems like it was increasingly
#
# 65
# 00:02:23,700 --> 00:02:26,000
# likely to some, the verge of spoken
#
# 66
# 00:02:26,000 --> 00:02:27,400
# to multiple sources, who claim that
#
# 67
# 00:02:27,400 --> 00:02:29,400
# during their time at 2. The company
#
# 68
# 00:02:29,400 --> 00:02:31,200
# valued speed and profit over the safety
#
# 69
# 00:02:31,200 --> 00:02:32,800
# of its users and the security of its
#
# 70
# 00:02:32,800 --> 00:02:35,400
# data this data breach which, which claims
#
# 71
# 00:02:35,400 --> 00:02:36,800
# on an heir to a server. Configuration
#
# 72
# 00:02:36,800 --> 00:02:39,000
# is the latest in a series of security
#
# 73
# 00:02:39,000 --> 00:02:40,500
# in moderation problems that have plagued,
#
# 74
# 00:02:40,500 --> 00:02:42,600
# the Amazon owned streaming platform
#
# 75
# 00:02:42,600 --> 00:02:45,100
# in August hate rates in which marginalized
#
# 76
# 00:02:45,100 --> 00:02:46,900
# rumors were subjected to uncontrollable
#
# 77
# 00:02:46,900 --> 00:02:48,900
# numbers about spamming hate speech erupted
#
# 78
# 00:02:48,900 --> 00:02:51,000
# across twitch streamers banded together
#
# 79
# 00:02:51,000 --> 00:02:53,200
# to create a Twitch, the twitch do better
#
# 80
# 00:02:53,200 --> 00:02:54,800
# hashtag and organize, a walk out on
#
# 81
# 00:02:54,800 --> 00:02:56,300
# September 1st to bring attention to
#
# 82
# 00:02:56,300 --> 00:02:58,200
# the problem in sport, which the employee
#
# 83
# 00:02:58,200 --> 00:03:00,600
# safety measures to stem to hate tide
#
# 84
# 00:03:00,600 --> 00:03:02,800
# in response to which acknowledge dreamers
#
# 85
# 00:03:02,800 --> 00:03:06,100
# complaints and promised. It was working
#
# 86
# 00:03:06,100 --> 00:03:07,400
# on tools, that would help to better
#
# 87
# 00:03:07,400 --> 00:03:09,300
# protect as groomers in their communities,
#
# 88
# 00:03:09,300 --> 00:03:11,500
# you're asking us to do better. And we
#
# 89
# 00:03:11,500 --> 00:03:13,000
# know we need to do more to address.
#
# 90
# 00:03:13,000 --> 00:03:15,200
# These issues Twitches said in its response,
#
# 91
# 00:03:15,200 --> 00:03:17,700
# but the Patriots didn't just suddenly
#
# 92
# 00:03:17,700 --> 00:03:19,200
# appear this summer. And according to
#
# 93
# 00:03:19,200 --> 00:03:21,100
# a former twitch employee alarms were
#
# 94
# 00:03:21,100 --> 00:03:22,600
# raised about the potential abuses of
#
# 95
# 00:03:22,600 --> 00:03:24,500
# raids long before their hate variety
#
# 96
# 00:03:24,500 --> 00:03:26,900
# exploded in August. One Source who spoke
#
# 97
# 00:03:26,900 --> 00:03:28,300
# to the verge on the condition of anonymity
#
# 98
# 00:03:28,300 --> 00:03:31,300
# worked at which, from 2017 to 2019.
#
# 99
# 00:03:31,300 --> 00:03:33,300
# They described an atmosphere where employees
#
# 100
# 00:03:33,300 --> 00:03:34,900
# were very concerned about safety but
#
# 101
# 00:03:34,900 --> 00:03:36,700
# management less. So than the article
#
# 102
# 00:03:36,700 --> 00:03:38,700
# continues and continues to, which has
#
# 103
# 00:03:38,700 --> 00:03:40,100
# not been having a great weekend, is
#
# 104
# 00:03:40,100 --> 00:03:42,400
# not uncommon, post breach or companies
#
# 105
# 00:03:42,400 --> 00:03:44,700
# get a closer or deeper examination of
#
# 106
# 00:03:44,700 --> 00:03:46,500
# their practices, and some things that
#
# 107
# 00:03:46,500 --> 00:03:48,000
# they may not want come to light.
